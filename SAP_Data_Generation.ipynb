# %% [markdown]
# # Use O2C_Template Customized Notebook Template

# %%
import random
from faker import Faker
import pandas as pd

# %%
from fosforml.model_manager.snowflakesession import get_session
my_session = get_session()

# %%
fake = Faker('en_US')

# %% [markdown]
# # Customer Data Setup

# %%
# Generate Customers
def generate_customers(num_customers=150):
    customers = []
    for _ in range(num_customers):
        customer = {
            'CustomerID': 'CID-' + fake.uuid4(),
            'CompanyType':fake.company_suffix(),
            'ContactDetails': fake.phone_number(),
            'EmailDetails': fake.company_email(),
            'AddressDetails':fake.address(),
            'AdminDetails':fake.administrative_unit(),
            'CreditLimit': random.randint(30000, 100000),
            'CustomerSince': f"YR-{random.randint(2015, 2022)}", 
            #'CreditRating': random.choice(['very poor', 'fair', 'good', 'very good','exceptional'])
        }
        customers.append(customer)
    return customers

# %%
# Generate Data
customers = generate_customers()

# %%
customers_name = ['CleverOffice','Stackers','PreScott Works','MomentA','BOXED'
,'JinkOffice','HomeEssentials','BallPoint','WhaleBack','Formica'
,'Starton Inc','Anabrige LLP','Hammers and Nails','BoreHole LLC'
,'Indra Secure Co-rp','CortiTech ITC','DOLCH ','Sutura'
,'StarStruck LLC','BARCTL LLC','Limae Inc','Rivet','Marathon'
,'Valiant','Filum','TautaLog','Pin&Fix','JamPack','MasterStik'
,'CLIC','Nestables','CAPSTASH','Tappit','MashMart','TruSource'
,'ODD Sends','Pen Scoop','ASCRIBE LLP','Wire works','EXPRESSR'
,'FULCRO','SOLID BOX','LYSIS Logo','CARDIOID','Herculean Inc'
,'OTTAVA','BLUE Ribbon','Master Bind ','Thinkies','Five Point'
,'Connect iBuy','Lion Mark','Deskify','BestTry','PLOTSHOP'
,'Office Fuel','Oasis Cuff','CoraPress','SuperShapes','BeeBows'
,'Locale Mart','TetherLink','Comestor','Knox Paper','NECESSITE'
,'Corner Spike','SPACE MAX','Easy Dealy','Star Tech','KLIXX'
,'Phyllon LLP','Planisphere','A1 Creased','ONYX','HomeBright'
,'NextBolt','Pinch Hops','Popplin','Mercer and Sons','Jackson-Hughes'
,'Moran Ltd','Baldwin PLC','Tucker Ltd','Allen Inc','Rodriguez Group'
,'Taylor Ltd','Mahoney PLC','Robinson Group','Mcmillan LLC'
,'Bailey-Roberts','Rivera PLC','Potter Group','Mckay-Davis','Valencia Group'
,'Haynes-Jackson','Klein Inc','Davis-Rose','Watson-Miller','Smith LLC'
,'Jackson and Sons'
,'BrightWorks', 'EcoSphere', 'TechWave', 'PrimeSource', 'Apex Innovations',
'GreenLeaf', 'UrbanEdge', 'Quantum Solutions', 'Vertex Ventures', 'NexGen',
'FusionCorp', 'BlueSky Enterprises', 'PioneerTech', 'Elite Systems', 'Skyline Industries',
'ProActive', 'Innovatech', 'CoreDynamics', 'SynergyWorks', 'NextEra',
'Optima', 'Zenith', 'Vanguard', 'Summit Solutions', 'Infinity Group',
'AlphaTech', 'GlobalReach', 'MetroLink', 'Visionary', 'DynamicEdge',
'PrimeTech', 'FutureWave', 'EcoTech', 'UrbanCore', 'SkyHigh',
'ProLink', 'Innovative Solutions', 'CoreTech', 'SynergyCorp', 'NextGen Solutions',
'OptiMax', 'Zenith Enterprises', 'Vanguard Innovations', 'SummitTech', 'Infinity Solutions',
'Alpha Innovations', 'GlobalTech', 'MetroTech', 'Visionary Solutions', 'Dynamic Innovations']

# %%
df_customers = pd.DataFrame(customers)

# %%
# Function to determine Payment_Terms based on CreditLimit
def determine_payment_terms(rating):
    if rating < 50000:
        return 'Net 15 days'
    elif 50000 <= rating < 75000:
        return 'Net 30 days'
    elif 75000 <= rating < 90000:
        return 'Net 45 days'
    else:
        return 'Net 60 days'

# %%
# Assign RatingType based on Rating value
df_customers['PaymentTerms'] = df_customers['CreditLimit'].apply(determine_payment_terms)

# %%
# Function to determine CreditLimitType based on CreditLimit/Rating value
def determine_rating_type(rating):
    if rating < 40000:
        return 'Very Low'
    elif 40000 <= rating < 55000:
        return 'Low'
    elif 55000 <= rating < 70000:
        return 'Medium'
    elif 70000 <= rating < 85000:
        return 'High'
    else:
        return 'Very High'

# %%
# Assign RatingType based on Rating value
df_customers['CreditLimitType'] = df_customers['CreditLimit'].apply(determine_rating_type)

# %%
df_customers['CustomerName'] = customers_name

# %%
CustomerType = ['Construction Materials','Office Supplies','Construction Materials','Food Beverages'
,'Office Supplies','Construction Materials','Healthcare','Food Beverages','Automotive'
,'Food Beverages','Food Beverages','Construction Materials','Construction Materials'
,'Construction Materials','Automotive','Food Beverages','Food Beverages','Food Beverages'
,'Consumer Goods','Consumer Goods','Healthcare','Office Supplies','Office Supplies'
,'Office Supplies','Healthcare','Office Supplies','Construction Materials','Office Supplies'
,'Office Supplies','Office Supplies','Food Beverages','Consumer Goods','Consumer Goods'
,'Food Beverages','Office Supplies','Office Supplies','Food Beverages','Office Supplies'
,'Construction Materials','Food Beverages','Automotive','Office Supplies','Office Supplies'
,'Consumer Goods','Automotive','Food Beverages','Office Supplies','Office Supplies'
,'Food Beverages','Food Beverages','Food Beverages','Food Beverages','Consumer Goods'
,'Healthcare','Food Beverages','Healthcare','Food Beverages','Food Beverages','Healthcare'
,'Automotive','Food Beverages','Food Beverages','Food Beverages','Consumer Goods'
,'Healthcare','Food Beverages','Automotive','Consumer Goods','Food Beverages'
,'Food Beverages','Consumer Goods','Consumer Goods','Automotive','Consumer Goods'
,'Consumer Goods','Construction Materials','Consumer Goods','Consumer Goods','Consumer Goods'
,'Consumer Goods','Industrial Equipment','Industrial Equipment','Industrial Equipment'
,'Industrial Equipment','Consumer Goods','Industrial Equipment','Healthcare','Healthcare'
,'Healthcare','Automotive','Industrial Equipment','Construction Materials','Automotive'
,'Construction Materials','Consumer Goods','Consumer Goods','Consumer Goods','Consumer Goods'
,'Industrial Equipment','Consumer Goods'
,'Office Supplies','Office Supplies','Office Supplies','Office Supplies','Office Supplies'
,'Consumer Goods','Consumer Goods','Consumer Goods','Consumer Goods','Consumer Goods'
,'Food Beverages','Food Beverages','Food Beverages','Food Beverages','Food Beverages'
,'Construction Materials','Construction Materials','Construction Materials','Construction Materials','Construction Materials'
,'Healthcare','Healthcare','Healthcare','Healthcare','Healthcare'
,'Automotive','Automotive','Automotive','Automotive','Automotive'
,'Industrial Equipment','Industrial Equipment','Industrial Equipment','Industrial Equipment','Industrial Equipment'
,'Office Supplies','Office Supplies','Office Supplies','Office Supplies','Office Supplies'
,'Consumer Goods','Consumer Goods','Consumer Goods','Consumer Goods','Consumer Goods'
,'Food Beverages','Food Beverages','Food Beverages','Food Beverages','Food Beverages']

# %%
df_customers['CustomerType'] = CustomerType

# %%
df_customers.columns
# Out:
# Index(['CustomerID', 'CompanyType', 'ContactDetails', 'EmailDetails',
#        'AddressDetails', 'AdminDetails', 'CreditLimit', 'CustomerSince',
#        'PaymentTerms', 'CreditLimitType', 'CustomerName', 'CustomerType'],
#       dtype='object')

# %%
df_customers.head()
# Out:
#                                  CustomerID CompanyType        ContactDetails  \
# 0  CID-8f625c7b-d43b-4436-80ad-4cbba77c779e         PLC  +1-875-276-6325x2418
# 1  CID-7defd2b6-7ee3-4371-bd5e-a34d6179ead7         Ltd     (537)281-7306x652
# 2  CID-2decf55f-b43b-42ab-a3a1-1d1b6c3d40a4         Ltd  001-824-063-1538x302
# 3  CID-a6c36d38-d2f8-4728-9e7f-6a6ca14d1928         LLC   +1-949-057-6105x819
# 4  CID-7b7ae865-2ef0-4330-8bb9-a2cfc2645003       Group       +1-159-031-2775
#
#                      EmailDetails  \
# 0       jacob45@bailey-murphy.net
# 1  romerojustin@moore-bentley.com
# 2    griffithsuzanne@anderson.com
# 3    mgonzalez@morales-massey.com
# 4          william48@martinez.com
#
#                                       AddressDetails   AdminDetails  \
# 0            033 Daniel Route\nMartinshire, IN 02876           Utah
# 1             6527 Ross Canyon\nCherylstad, OH 67499        Vermont
# 2  49148 Mclaughlin Groves Suite 661\nJoannemouth...   South Dakota
# 3                           USNS Kline\nFPO AP 68761   Rhode Island
# 4  494 Jamie Mountains Apt. 435\nSouth Tonifort, ...  New Hampshire
#
#    CreditLimit CustomerSince PaymentTerms CreditLimitType    CustomerName  \
# 0        53429       YR-2019  Net 30 days             Low    CleverOffice
# 1        87832       YR-2022  Net 45 days       Very High        Stackers
# 2        94936       YR-2016  Net 60 days       Very High  PreScott Works
# 3        30025       YR-2016  Net 15 days        Very Low         MomentA
# 4        57617       YR-2022  Net 30 days          Medium           BOXED
#
#              CustomerType
# 0  Construction Materials
# 1         Office Supplies
# 2  Construction Materials
# 3          Food Beverages
# 4         Office Supplies

# %%
df_train_sf=my_session.createDataFrame(
        df_customers.values.tolist(),
        schema=df_customers.columns.tolist())
df_train_sf.write.mode("overwrite").save_as_table("FDC_HORIZONTAL.O2C_BRONZE.KNA1")

# %% [markdown]
# # Product Data setup

# %%
df_product = pd.read_csv('product_files.csv')

# %%
df_product.shape
# Out:
# (72, 6)

# %%
df_product.head()
# Out:
#    ProductCategory            ProductType  Quantity  UnitPrice SupplierName  \
# 0  Office Supplies          Laser Printer       100        425  Sure Source
# 1  Office Supplies        Ergonomic Chair      1000        299  Sure Source
# 2  Office Supplies          Standing Desk      1000        420  Sure Source
# 3  Office Supplies      Wireless Keyboard      1000         78  Sure Source
# 4  Office Supplies  Office Stationery Set      1000         15  Sure Source
#
#                                   SupplierID
# 0  SUP--8f625c7b-d43b-4436-80ad-4cbba77c779e
# 1  SUP--8f625c7b-d43b-4436-80ad-4cbba77c779e
# 2  SUP--8f625c7b-d43b-4436-80ad-4cbba77c779e
# 3  SUP--8f625c7b-d43b-4436-80ad-4cbba77c779e
# 4  SUP--8f625c7b-d43b-4436-80ad-4cbba77c779e

# %%
def generate_products(data):
    data['ProductID'] = ''
    # Iterate over rows and columns
    for index, row in data.iterrows():
        data.at[index, 'ProductID'] = 'PID-' + fake.uuid4()
    return data

# %%
df_product = generate_products(df_product)

# %%
df_product.columns
# Out:
# Index(['ProductCategory', 'ProductType', 'Quantity', 'UnitPrice',
#        'SupplierName', 'SupplierID', 'ProductID'],
#       dtype='object')

# %%
df_train_sf=my_session.createDataFrame(
        df_product.values.tolist(),
        schema=df_product.columns.tolist())
df_train_sf.write.mode("overwrite").save_as_table("FDC_HORIZONTAL.O2C_BRONZE.MARA")

# %% [markdown]
# # Status Scenarios for data Manipulation

# %%
order_status = ['Approved','Rejected','Cancelled']
shipment_status = ['Pending','Picked','Shipped','In-Transit','Delivered','Returned']
invoice_status = ['PendingApproval','Approved','Sent','Paid','Cancelled']

# %%
import itertools

# %%
# Generate all possible combinations of statuses
combinations = list(itertools.product(order_status,shipment_status,invoice_status))

# %%
# Create a DataFrame to store the combinations
columns = ["order_status", "shipment_status", "invoice_status"]
df = pd.DataFrame(combinations, columns=columns)

# %%
df[df['order_status']=='Approved']
# Out:
#    order_status shipment_status   invoice_status
# 0      Approved         Pending  PendingApproval
# 1      Approved         Pending         Approved
# 2      Approved         Pending             Sent
# 3      Approved         Pending             Paid
# 4      Approved         Pending        Cancelled
# 5      Approved          Picked  PendingApproval
# 6      Approved          Picked         Approved
# 7      Approved          Picked             Sent
# 8      Approved          Picked             Paid
# 9      Approved          Picked        Cancelled
# 10     Approved         Shipped  PendingApproval
# 11     Approved         Shipped         Approved
# 12     Approved         Shipped             Sent
# 13     Approved         Shipped             Paid
# 14     Approved         Shipped        Cancelled
# 15     Approved      In-Transit  PendingApproval
# 16     Approved      In-Transit         Approved
# 17     Approved      In-Transit             Sent
# 18     Approved      In-Transit             Paid
# 19     Approved      In-Transit        Cancelled
# 20     Approved       Delivered  PendingApproval
# 21     Approved       Delivered         Approved
# 22     Approved       Delivered             Sent
# 23     Approved       Delivered             Paid
# 24     Approved       Delivered        Cancelled
# 25     Approved        Returned  PendingApproval
# 26     Approved        Returned         Approved
# 27     Approved        Returned             Sent
# 28     Approved        Returned             Paid
# 29     Approved        Returned        Cancelled

# %% [markdown]
# # Setup Order, OrderItems, Shipment and Invoice Data for Fulfilled Orders

# %%
from fosforml.model_manager.snowflakesession import get_session
my_session = get_session()

# %%
table_name = 'KNA1'

sf_df = my_session.sql("select * from {}".format(table_name))
df_customers = sf_df.to_pandas()
# Out:
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[77], line 4
#       1 table_name = 'KNA1'
#       3 sf_df = my_session.sql("select * from {}".format(table_name))
# ----> 4 df_customers = sf_df.to_pandas()
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/telemetry.py:156, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     153 @functools.wraps(func)
#     154 def wrap(*args, **kwargs):
#     155     with args[0]._session.query_history() as query_history:
# --> 156         result = func(*args, **kwargs)
#     157     plan = args[0]._select_statement or args[0]._plan
#     158     api_calls = [
#     159         *plan.api_calls,
#     160         {TelemetryField.NAME.value: f"DataFrame.{func.__name__}"},
#     161     ]
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/dataframe.py:807, in DataFrame.to_pandas(self, statement_params, block, **kwargs)
#     788 """
#     789 Executes the query representing this DataFrame and returns the result as a
#     790 `pandas DataFrame <https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html>`_.
#    (...)
#     804     :func:`Session.sql` can only be a SELECT statement.
#     805 """
#     806 with open_telemetry_context_manager(self.to_pandas, self):
# --> 807     result = self._session._conn.execute(
#     808         self._plan,
#     809         to_pandas=True,
#     810         block=block,
#     811         data_type=_AsyncResultType.PANDAS,
#     812         _statement_params=create_or_update_statement_params_with_query_tag(
#     813             statement_params or self._statement_params,
#     814             self._session.query_tag,
#     815             SKIP_LEVELS_TWO,
#     816         ),
#     817         **kwargs,
#     818     )
#     820 # if the returned result is not a pandas dataframe, raise Exception
#     821 # this might happen when calling this method with non-select commands
#     822 # e.g., session.sql("create ...").to_pandas()
#     823 if block:
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:526, in ServerConnection.execute(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     516 if (
#     517     is_in_stored_procedure()
#     518     and not block
#    (...)
#     521     )
#     522 ):  # pragma: no cover
#     523     raise NotImplementedError(
#     524         "Async query is not supported in stored procedure yet"
#     525     )
# --> 526 result_set, result_meta = self.get_result_set(
#     527     plan,
#     528     to_pandas,
#     529     to_iter,
#     530     **kwargs,
#     531     block=block,
#     532     data_type=data_type,
#     533     log_on_exception=log_on_exception,
#     534     case_sensitive=case_sensitive,
#     535 )
#     536 if not block:
#     537     return result_set
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:207, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     203 else:
#     204     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     205         e
#     206     )
# --> 207     raise ne.with_traceback(tb) from None
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:138, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     136 def wrap(*args, **kwargs):
#     137     try:
# --> 138         return func(*args, **kwargs)
#     139     except snowflake.connector.errors.ProgrammingError as e:
#     140         query = getattr(e, "query", None)
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:633, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, ignore_results, **kwargs)
#     631 for holder, id_ in placeholders.items():
#     632     final_query = final_query.replace(holder, id_)
# --> 633 result = self.run_query(
#     634     final_query,
#     635     to_pandas,
#     636     to_iter and (i == len(main_queries) - 1),
#     637     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     638     block=not is_last,
#     639     data_type=data_type,
#     640     async_job_plan=plan,
#     641     log_on_exception=log_on_exception,
#     642     case_sensitive=case_sensitive,
#     643     params=query.params,
#     644     ignore_results=ignore_results,
#     645     **kwargs,
#     646 )
#     647 placeholders[query.query_id_place_holder] = (
#     648     result["sfqid"] if not is_last else result.query_id
#     649 )
#     650 result_meta = get_new_description(self._cursor)
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:125, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     121     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     122         ex.cause
#     123     )
#     124 except Exception as ex:
# --> 125     raise ex
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:119, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     117     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#     118 try:
# --> 119     return func(*args, **kwargs)
#     120 except ReauthenticationRequest as ex:
#     121     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     122         ex.cause
#     123     )
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:433, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, **kwargs)
#     431         query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     432         logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 433     raise ex
#     435 # fetch_pandas_all/batches() only works for SELECT statements
#     436 # We call fetchall() if fetch_pandas_all/batches() fails,
#     437 # because when the query plan has multiple queries, it will
#     438 # have non-select statements, and it shouldn't fail if the user
#     439 # calls to_pandas() to execute the query.
#     440 if block:
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:418, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, **kwargs)
#     416     kwargs["_statement_params"]["SNOWPARK_SKIP_TXN_COMMIT_IN_DDL"] = True
#     417 if block:
# --> 418     results_cursor = self.execute_and_notify_query_listener(
#     419         query, params=params, **kwargs
#     420     )
#     421     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#     422 else:
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:369, in ServerConnection.execute_and_notify_query_listener(self, query, **kwargs)
#     366 def execute_and_notify_query_listener(
#     367     self, query: str, **kwargs: Any
#     368 ) -> SnowflakeCursor:
# --> 369     results_cursor = self._cursor.execute(query, **kwargs)
#     370     self.notify_query_listeners(
#     371         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     372     )
#     373     return results_cursor
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/cursor.py:1087, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _dataframe_ast)
#    1083     is_integrity_error = (
#    1084         code == "100072"
#    1085     )  # NULL result in a non-nullable column
#    1086     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1087     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1088 return self
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/errors.py:284, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     261 @staticmethod
#     262 def errorhandler_wrapper(
#     263     connection: SnowflakeConnection | None,
#    (...)
#     266     error_value: dict[str, Any],
#     267 ) -> None:
#     268     """Error handler wrapper that calls the errorhandler method.
#     269
#     270     Args:
#    (...)
#     281         exception to the first handler in that order.
#     282     """
# --> 284     handed_over = Error.hand_to_other_handler(
#     285         connection,
#     286         cursor,
#     287         error_class,
#     288         error_value,
#     289     )
#     290     if not handed_over:
#     291         raise Error.errorhandler_make_exception(
#     292             error_class,
#     293             error_value,
#     294         )
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/errors.py:339, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     337 if cursor is not None:
#     338     cursor.messages.append((error_class, error_value))
# --> 339     cursor.errorhandler(connection, cursor, error_class, error_value)
#     340     return True
#     341 elif connection is not None:
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/errors.py:215, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     213 errno = error_value.get("errno")
#     214 done_format_msg = error_value.get("done_format_msg")
# --> 215 raise error_class(
#     216     msg=error_value.get("msg"),
#     217     errno=None if errno is None else int(errno),
#     218     sqlstate=error_value.get("sqlstate"),
#     219     sfqid=error_value.get("sfqid"),
#     220     query=error_value.get("query"),
#     221     done_format_msg=(
#     222         None if done_format_msg is None else bool(done_format_msg)
#     223     ),
#     224     connection=connection,
#     225     cursor=cursor,
#     226 )
#
# SnowparkSQLException: (1304): 01b7597b-0711-8e27-0072-f3031235316a: 002003 (42S02): SQL compilation error:
# Object 'KNA1' does not exist or not authorized.

# %%
table_name = 'MARA'

sf_df = my_session.sql("select * from {}".format(table_name))
df_product = sf_df.to_pandas()

# %%
# Assuming you already have the customers and products dataframes
customers = df_customers['CUSTOMERID'].tolist()
products = df_product[['PRODUCTID', 'UNITPRICE']].to_dict('records')

# %%
# Function to generate a random date between two dates
def random_date(start_date, end_date):
    delta = end_date - start_date
    random_days = random.randint(0, delta.days)
    return start_date + timedelta(days=random_days)

# %%
# Define the date range
from datetime import datetime, timedelta

start_date = datetime.strptime('08-01-2022', '%m-%d-%Y')
end_date = datetime.strptime('09-01-2024', '%m-%d-%Y')

# %%
def add_days(input_date, range1, range2):

    if isinstance(input_date, str):    
    # Convert orderdate string back to datetime object
        input_date = datetime.strptime(input_date, '%m-%d-%Y')

    # Generate a random number of days 
    additional_days = random.randint(range1, range2)

    # Calculate the new date
    new_date = input_date + timedelta(days=additional_days)

    # Convert the new date back to string if needed
    new_date = new_date.strftime('%m-%d-%Y')

    return new_date

# %%
df_product
# Out:
#     PRODUCTCATEGORY            PRODUCTTYPE  QUANTITY  UNITPRICE  \
# 0   Office Supplies          Laser Printer       100        425
# 1   Office Supplies        Ergonomic Chair      1000        299
# 2   Office Supplies          Standing Desk      1000        420
# 3   Office Supplies      Wireless Keyboard      1000         78
# 4   Office Supplies  Office Stationery Set      1000         15
# ..              ...                    ...       ...        ...
# 67      Electronics        Fitness Tracker      1000         99
# 68      Electronics       Portable Speaker       300         79
# 69      Electronics               Smart TV       200        420
# 70      Electronics             VR Headset       100        121
# 71      Electronics         Digital Camera       100        189
#
#                                    PRODUCTID
# 0   PID-6c8ebf15-ba14-4564-8fec-7abe5c8ab206
# 1   PID-152a2d71-4427-49ac-a84a-9720e73f4ac0
# 2   PID-864a09fa-9bc8-4ed2-b359-ed841b78bd0b
# 3   PID-d18f3fd3-7ad9-42be-b495-ba2c35ebe2f6
# 4   PID-91e2aa75-da02-471e-ba2f-17e8e4f99643
# ..                                       ...
# 67  PID-882ce1ec-d65b-493f-869f-537ec3c4caae
# 68  PID-d09722d9-6adc-4967-bebd-526323668a31
# 69  PID-bdf323ef-0ee8-485a-a0af-01aef550a564
# 70  PID-0755fae2-bae5-4b0a-966a-c9377a70be91
# 71  PID-db1d4530-5149-40b9-ae5d-356b6bf4162c
#
# [72 rows x 5 columns]

# %%
# List to store orders
orders_fulfill = []
items_fulfill = []
shipment_fulfill = []
invoice_fulfill = []

# Generate orders
for i in range(85000):
    # Filter products matching the customer's type
    customer = df_customers.sample(n=1)
    matching_products = df_product[df_product['PRODUCTCATEGORY'] == customer.iloc[0]['CUSTOMERTYPE']]
    num_items = random.choice([1,2,3])  # Each order has a random number of items between 1 and 3

    customerid = customer.iloc[0]['CUSTOMERID']
    orderid = 'OR-' + fake.uuid4()
    orderdate = random_date(start_date, end_date).strftime('%m-%d-%Y')
    orderstatus = 'Approved'
    orderamount = 0
    ordercount = 0
    
    shipmentid = 'SP-' + fake.uuid4()
    shipmentdate = add_days(orderdate, 2,7)
    deliverydate = add_days(shipmentdate, 1,4)
    deliveredOn = add_days(deliverydate,0,3) 

    invoiceid = 'IN-' + fake.uuid4()
    invoicedate = add_days(deliveredOn,0,2)
    invoiceduedate = add_days(invoicedate,5,7)
    
    paymentdate = add_days(invoicedate,1,15)
    
    for _ in range(num_items):
        products = matching_products.sample(n=1)
        product_type = products.iloc[0]['PRODUCTTYPE']
        quantity = random.randint(1, products.iloc[0]['QUANTITY'])  # Generate a random quantity for each order item
        unit_price = products.iloc[0]['UNITPRICE']
        total_price = quantity * unit_price
        orderamount += total_price
        ordercount += 1
        matching_products = matching_products[matching_products['PRODUCTTYPE'] != product_type]
        orderitemid = 'OI-' + fake.uuid4()


        items_dict = {
            'ORDERID' : orderid,
            'ORDERITEMID': orderitemid,
            'PRODUCTID': products.iloc[0]['PRODUCTID'],
            'PRODUCTNAME' : products.iloc[0]['PRODUCTTYPE'],
            'ORDERQUANTITY' :quantity,
            'UNITPRICE' : unit_price,
            'ORDERVALUE' : total_price
        }

        items_fulfill.append(items_dict)

    orders_dict = {
        'ORDERID' : orderid,
        'CUSTOMERID': customerid,
        'CUSTOMERNAME': customer.iloc[0]['CUSTOMERNAME'],
        'PRODUCTID': matching_products.iloc[0]['PRODUCTID'],
        'PRODUCTCATEGORY': matching_products.iloc[0]['PRODUCTCATEGORY'],
        'ORDERDATE': orderdate,
        'ORDERSTATUS': orderstatus,
        'ORDERAMOUNT' :orderamount,
        'ORDERCOUNT' : ordercount
    }

    orders_fulfill.append(orders_dict)

    shipment_dict = {
        'SHIPMENTID': shipmentid,
        'ORDERID' : orderid,
        'SHIPMENTDATE': shipmentdate,
        'DELIVERYDATE': deliverydate,
        'DELIVEREDON' :deliveredOn,
        'CARRIER' : random.choice(['FedEx', 'UPS', 'DHL', 'USPS']),
        'SHIPMENTSTATUS' : 'Delivered'
    }

    shipment_fulfill.append(shipment_dict)

    invoice_dict = {
        'INVOICEID': invoiceid,
        'ORDERID' : orderid,
        'INVOICEDATE': invoicedate,
        'INVOICEDUEDATE': invoiceduedate,
        'PAYMENTDATE' : paymentdate,
        'INVOICESTATUS': 'Paid',
        'PAYMENTMETHOD': random.choice(['Wire Transfers','Cards','Cash','Checks','Mobile Payments'])
    }

    invoice_fulfill.append(invoice_dict)

# %%
# Create a DataFrame for orders
df_orders_fulfill = pd.DataFrame(orders_fulfill)
df_items_fulfill = pd.DataFrame(items_fulfill)
df_shipment_fulfill = pd.DataFrame(shipment_fulfill)
df_invoice_fulfill = pd.DataFrame(invoice_fulfill)

# %%
df_orders_fulfill.head()
# Out:
#                                    ORDERID  \
# 0  OR-1d383f77-5592-46ad-8e52-29d33a6502ad
# 1  OR-343ce41a-322b-4823-8afc-52242973d163
# 2  OR-1310822f-e948-4c29-8da7-beec09196076
# 3  OR-e849443f-72a5-4c49-a918-259823ccc1e9
# 4  OR-978ac247-05c3-4847-9d12-d4b9d2910a5a
#
#                                  CUSTOMERID         CUSTOMERNAME  \
# 0  CID-4a14e75e-cd20-44a1-9696-d5eb1746b894         Anabrige LLP
# 1  CID-f922f515-1a7a-4640-959a-3c2f093f4d47               FULCRO
# 2  CID-169eb6d1-27a1-4859-b7c8-5073ca1eb201           Taylor Ltd
# 3  CID-03ffafe5-c975-4691-9124-d7c65cdcef54          PrimeSource
# 4  CID-e055738a-560d-469c-9e7e-2c27a25177b5  Visionary Solutions
#
#                                   PRODUCTID         PRODUCTCATEGORY  \
# 0  PID-55b88cce-96d6-4313-9bf8-34e33a50a631  Construction Materials
# 1  PID-caa3a675-a1ad-4440-abe9-ae817c1c1619              Automotive
# 2  PID-0dcaa3ac-5e13-4b31-b42a-70b594207dab    Industrial Equipment
# 3  PID-6c8ebf15-ba14-4564-8fec-7abe5c8ab206         Office Supplies
# 4  PID-4eba2d8a-acc7-4a48-8e25-517ce536b3f8          Food Beverages
#
#     ORDERDATE ORDERSTATUS  ORDERAMOUNT  ORDERCOUNT
# 0  01-08-2023    Approved        26935           3
# 1  05-28-2023    Approved        10520           1
# 2  09-07-2023    Approved      3306000           2
# 3  12-26-2022    Approved        14820           1
# 4  12-22-2022    Approved        51354           3

# %%
df_shipment_fulfill.head(5)
# Out:
#                                 SHIPMENTID  \
# 0  SP-18950f50-c520-4bdc-97ab-d63f4013b235
# 1  SP-4768c057-a294-4af7-8e78-8f1edbe78729
# 2  SP-bbad4c04-00f8-4fdf-81c7-d476ead98c5a
# 3  SP-1dbcbd83-c266-4431-bd6a-7c0b39d03474
# 4  SP-c741f95c-bfc4-4994-b113-c10ca66602c0
#
#                                    ORDERID SHIPMENTDATE DELIVERYDATE  \
# 0  OR-1d383f77-5592-46ad-8e52-29d33a6502ad   01-14-2023   01-15-2023
# 1  OR-343ce41a-322b-4823-8afc-52242973d163   05-31-2023   06-01-2023
# 2  OR-1310822f-e948-4c29-8da7-beec09196076   09-10-2023   09-14-2023
# 3  OR-e849443f-72a5-4c49-a918-259823ccc1e9   12-29-2022   12-31-2022
# 4  OR-978ac247-05c3-4847-9d12-d4b9d2910a5a   12-26-2022   12-29-2022
#
#   DELIVEREDON CARRIER SHIPMENTSTATUS
# 0  01-15-2023   FedEx      Delivered
# 1  06-01-2023     UPS      Delivered
# 2  09-17-2023     DHL      Delivered
# 3  01-02-2023   FedEx      Delivered
# 4  12-29-2022     UPS      Delivered

# %%
df_invoice_fulfill.head(5)
# Out:
#                                  INVOICEID  \
# 0  IN-64d9efd0-2df3-46c1-b702-243bcebca0b3
# 1  IN-f26528f2-18fe-4a40-9799-dc0b9e8d41d7
# 2  IN-825367b4-e037-4958-a0c4-8099a1731e30
# 3  IN-449fe1c9-fb59-4704-9d23-8f93b0f31d85
# 4  IN-ea7ed9ae-ca00-497f-b0a8-b6e127b6de0c
#
#                                    ORDERID INVOICEDATE INVOICEDUEDATE  \
# 0  OR-1d383f77-5592-46ad-8e52-29d33a6502ad  01-17-2023     01-22-2023
# 1  OR-343ce41a-322b-4823-8afc-52242973d163  06-03-2023     06-08-2023
# 2  OR-1310822f-e948-4c29-8da7-beec09196076  09-19-2023     09-26-2023
# 3  OR-e849443f-72a5-4c49-a918-259823ccc1e9  01-02-2023     01-09-2023
# 4  OR-978ac247-05c3-4847-9d12-d4b9d2910a5a  12-29-2022     01-04-2023
#
#   PAYMENTDATE INVOICESTATUS   PAYMENTMETHOD
# 0  01-19-2023          Paid  Wire Transfers
# 1  06-16-2023          Paid  Wire Transfers
# 2  09-24-2023          Paid  Wire Transfers
# 3  01-12-2023          Paid           Cards
# 4  01-11-2023          Paid            Cash

# %% [markdown]
# # Setup Order, OrderItems, Shipment and Invoice Data for recent Pending Orders

# %%
# List to store orders
orders_fulfill_1 = []
items_fulfill_1 = []
shipment_fulfill_1 = []
invoice_fulfill_1 = []

start_date = datetime.strptime('08-15-2024', '%m-%d-%Y')
end_date = datetime.strptime('09-15-2024', '%m-%d-%Y')

# Generate orders
for i in range(1500):
    # Filter products matching the customer's type
    customer = df_customers.sample(n=1)
    matching_products = df_product[df_product['PRODUCTCATEGORY'] == customer.iloc[0]['CUSTOMERTYPE']]
    num_items = random.choice([1,2,3])  # Each order has a random number of items between 1 and 3

    customerid = customer.iloc[0]['CUSTOMERID']
    orderid = 'OR-' + fake.uuid4()
    orderdate = random_date(start_date, end_date).strftime('%m-%d-%Y')
    orderstatus = 'Approved'
    orderamount = 0
    ordercount = 0
    
    shipmentid = 'SP-' + fake.uuid4()
    shipmentdate = add_days(orderdate, 2,7)
    deliverydate = add_days(shipmentdate, 1,4)
    deliveredOn = add_days(deliverydate,0,3) 

    invoiceid = 'IN-' + fake.uuid4()
    invoicedate = add_days(deliveredOn,0,2)
    invoiceduedate = add_days(invoicedate,5,7)
    paymentdate = add_days(invoicedate,1,15)

    shipment_status =  random.choice(['Picked','Shipped','In-Transit','Delivered'])
    invoice_status = ''
    if shipment_status == 'Delivered':
        invoice_status = 'Sent'
    else:
        invoice_status = random.choice(['PendingApproval','Approved'])
        invoicedate = '12-31-9999'
        invoiceduedate = '12-31-9999'
        paymentdate = '12-31-9999'
        deliveredOn = '12-31-9999'

    for _ in range(num_items):
        products = matching_products.sample(n=1)
        product_type = products.iloc[0]['PRODUCTTYPE']
        quantity = random.randint(1, products.iloc[0]['QUANTITY'])  # Generate a random quantity for each order item
        unit_price = products.iloc[0]['UNITPRICE']
        total_price = quantity * unit_price
        orderamount += total_price
        ordercount += 1
        matching_products = matching_products[matching_products['PRODUCTTYPE'] != product_type]
        orderitemid = 'OI-' + fake.uuid4()
        
        items_dict = {
            'ORDERID' : orderid,
            'ORDERITEMID': orderitemid,
            'PRODUCTID': products.iloc[0]['PRODUCTID'],
            'PRODUCTNAME' : products.iloc[0]['PRODUCTTYPE'],
            'ORDERQUANTITY' :quantity,
            'UNITPRICE' : unit_price,
            'ORDERVALUE' : total_price
        }

        items_fulfill_1.append(items_dict)

    orders_dict = {
        'ORDERID' : orderid,
        'CUSTOMERID': customerid,
        'CUSTOMERNAME': customer.iloc[0]['CUSTOMERNAME'],
        'PRODUCTID': matching_products.iloc[0]['PRODUCTID'],
        'PRODUCTCATEGORY': matching_products.iloc[0]['PRODUCTCATEGORY'],
        'ORDERDATE': orderdate,
        'ORDERSTATUS': orderstatus,
        'ORDERAMOUNT' :orderamount,
        'ORDERCOUNT' : ordercount
    }

    orders_fulfill_1.append(orders_dict)

    shipment_dict = {
        'SHIPMENTID': shipmentid,
        'ORDERID' : orderid,
        'SHIPMENTDATE': shipmentdate,
        'DELIVERYDATE': deliverydate,
        'DELIVEREDON' :deliveredOn,
        'CARRIER' : random.choice(['FedEx', 'UPS', 'DHL', 'USPS']),
        'SHIPMENTSTATUS' : shipment_status
    }

    shipment_fulfill_1.append(shipment_dict)

    invoice_dict = {
        'INVOICEID': invoiceid,
        'ORDERID' : orderid,
        'INVOICEDATE': invoicedate,
        'INVOICEDUEDATE': invoiceduedate,
        'PAYMENTDATE' : paymentdate,
        'INVOICESTATUS': invoice_status,
        'PAYMENTMETHOD': 'Not-Applicable'
    }

    invoice_fulfill_1.append(invoice_dict)

# %%
# Create a DataFrame for orders
df_orders_fulfill_1 = pd.DataFrame(orders_fulfill_1)
df_items_fulfill_1 = pd.DataFrame(items_fulfill_1)
df_shipment_fulfill_1 = pd.DataFrame(shipment_fulfill_1)
df_invoice_fulfill_1 = pd.DataFrame(invoice_fulfill_1)

# %%
df_orders_fulfill_1.head(2)
# Out:
#                                    ORDERID  \
# 0  OR-317f9ac8-48fa-475e-8291-fde9a3bbc495
# 1  OR-978c7c6c-a537-4c6c-b6c2-cb7b69a20f2d
#
#                                  CUSTOMERID  CUSTOMERNAME  \
# 0  CID-213f052b-75af-493d-b3e6-c0bbefc50c32        DOLCH
# 1  CID-7612689c-cd66-444b-b32b-982f37953ce9  CleverOffice
#
#                                   PRODUCTID         PRODUCTCATEGORY  \
# 0  PID-4eba2d8a-acc7-4a48-8e25-517ce536b3f8          Food Beverages
# 1  PID-89334032-db8d-4821-a9ad-5bd9a5305740  Construction Materials
#
#     ORDERDATE ORDERSTATUS  ORDERAMOUNT  ORDERCOUNT
# 0  08-26-2024    Approved         1107           1
# 1  09-01-2024    Approved        34909           1

# %%
df_items_fulfill_1.head(2)
# Out:
#                                    ORDERID  \
# 0  OR-317f9ac8-48fa-475e-8291-fde9a3bbc495
# 1  OR-978c7c6c-a537-4c6c-b6c2-cb7b69a20f2d
#
#                                ORDERITEMID  \
# 0  OI-d852cf78-88a0-49fa-8289-861b4c9cbe6b
# 1  OI-7c7c1b8a-fa38-4c29-b32b-d0501fc34182
#
#                                   PRODUCTID     PRODUCTNAME  ORDERQUANTITY  \
# 0  PID-ab3f0526-0015-47a8-b6a9-22cbe7e10459    Greek Yogurt            369
# 1  PID-3e2ce142-a70d-4da4-8770-2079f75f43a9  Roofing Sheets           4987
#
#    UNITPRICE  ORDERVALUE
# 0          3        1107
# 1          7       34909

# %%
df_shipment_fulfill_1.head()
# Out:
#                                 SHIPMENTID  \
# 0  SP-8bee22b1-6917-482a-995a-cd353fab3ded
# 1  SP-bb165010-5798-4feb-b9dc-9d1be7574cca
# 2  SP-05ed02a0-dc1d-4400-a64e-228812c85109
# 3  SP-4649159b-6fc9-4228-8491-aa1276d09008
# 4  SP-37cf7c51-5028-422e-9b61-5871a76f7029
#
#                                    ORDERID SHIPMENTDATE DELIVERYDATE  \
# 0  OR-317f9ac8-48fa-475e-8291-fde9a3bbc495   09-01-2024   09-04-2024
# 1  OR-978c7c6c-a537-4c6c-b6c2-cb7b69a20f2d   09-07-2024   09-08-2024
# 2  OR-d5c539e4-d1e3-41b8-a6e0-ffa39b203352   09-04-2024   09-06-2024
# 3  OR-c27de121-d8e8-4149-8bfb-853a6831c9bf   08-27-2024   08-30-2024
# 4  OR-a59070d9-4d6c-45ba-a33b-8e118b7b431e   08-31-2024   09-04-2024
#
#   DELIVEREDON CARRIER SHIPMENTSTATUS
# 0  12-31-9999   FedEx         Picked
# 1  12-31-9999    USPS     In-Transit
# 2  12-31-9999    USPS     In-Transit
# 3  08-30-2024     UPS      Delivered
# 4  09-06-2024     DHL      Delivered

# %%
df_invoice_fulfill_1.head(3)
# Out:
#                                  INVOICEID  \
# 0  IN-951e1d02-11c2-4a0d-96b3-aeea5cf80155
# 1  IN-b78e585a-c18f-4bc3-a094-2cef0dddd4ab
# 2  IN-364eda26-7d13-4fcd-8dc7-3b6c7f44d335
#
#                                    ORDERID INVOICEDATE INVOICEDUEDATE  \
# 0  OR-317f9ac8-48fa-475e-8291-fde9a3bbc495  12-31-9999     12-31-9999
# 1  OR-978c7c6c-a537-4c6c-b6c2-cb7b69a20f2d  12-31-9999     12-31-9999
# 2  OR-d5c539e4-d1e3-41b8-a6e0-ffa39b203352  12-31-9999     12-31-9999
#
#   PAYMENTDATE    INVOICESTATUS   PAYMENTMETHOD
# 0  12-31-9999  PendingApproval  Not-Applicable
# 1  12-31-9999  PendingApproval  Not-Applicable
# 2  12-31-9999  PendingApproval  Not-Applicable

# %%
df_orders = pd.concat([df_orders_fulfill,df_orders_fulfill_1],axis=0)
df_items = pd.concat([df_items_fulfill, df_items_fulfill_1],axis=0)
df_shipments = pd.concat([df_shipment_fulfill, df_shipment_fulfill_1],axis=0)
df_invoice = pd.concat([df_invoice_fulfill, df_invoice_fulfill_1],axis=0)

# %%
df_orders.shape
# Out:
# (86500, 9)

# %%
df_items.shape
# Out:
# (173291, 7)

# %%
df_shipments.shape
# Out:
# (86500, 7)

# %%
df_invoice.shape
# Out:
# (86500, 7)

# %% [markdown]
# # Push Data to Snowflake

# %%
df_train_sf=my_session.createDataFrame(
        df_orders.values.tolist(),
        schema=df_orders.columns.tolist())
df_train_sf.write.mode("overwrite").save_as_table("FDC_HORIZONTAL.O2C_BRONZE.ORDERS_DATA")

# %%
df_train_sf=my_session.createDataFrame(
        df_items.values.tolist(),
        schema=df_items.columns.tolist())
df_train_sf.write.mode("overwrite").save_as_table("FDC_HORIZONTAL.O2C_BRONZE.ITEMS_DATA")

# %%
df_train_sf=my_session.createDataFrame(
        df_shipments.values.tolist(),
        schema=df_shipments.columns.tolist())
df_train_sf.write.mode("overwrite").save_as_table("FDC_HORIZONTAL.O2C_BRONZE.SHIPMENTS_DATA")

# %%
df_train_sf=my_session.createDataFrame(
        df_invoice.values.tolist(),
        schema=df_invoice.columns.tolist())
df_train_sf.write.mode("overwrite").save_as_table("FDC_HORIZONTAL.O2C_BRONZE.INVOICE_DATA")
